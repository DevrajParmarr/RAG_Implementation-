# %% [markdown]
# # Welcome to Jupyter Notebook in VS Code
#
# This notebook is set up to work like Google Colab in your VS Code environment.

# %%
# Basic Python program
print('Hello, World!')
x = 5
y = 10
print('Sum:', x + y)
